# %%
import os
import shutil
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/dogvscat
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/dogvscat

# %%
# !pip install timm

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import torchvision
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import os
import shutil
from sklearn.model_selection import train_test_split
import timm  # Importing timm for Vision Transformer models

# Source and target directories
source_dir = './images'
binary_dir = './binary_classification'
multiclass_dir = './multiclass_classification'


# Split data into train and test directories
binary_source_dir = './binary_classification'
binary_train_dir = './train_binary'
binary_test_dir = './test_binary'
multiclass_source_dir = './multiclass_classification'
multiclass_train_dir = './train_multiclass'
multiclass_test_dir = './test_multiclass'

device = torch.device("cuda:0")

# Load a pre-trained Vision Transformer model
model = timm.create_model('vit_base_patch16_224', pretrained=True)
model = model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]

# %%
# Freeze all parameters and replace the classifier head
for param in model.parameters():
    param.requires_grad = False
num_features = model.head.in_features
model.head = nn.Linear(num_features, 37).to(device)

# Data transformations
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Dataset and DataLoader
train_dataset = datasets.ImageFolder(root=binary_train_dir, transform=transform)
test_dataset = datasets.ImageFolder(root=binary_test_dir, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Optimizer setup
optimizer = Adam(model.head.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss().to(device)

# Training Function
def train_model(model, criterion, optimizer, num_epochs=1):
    model.train()
    for epoch in range(num_epochs):
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Evaluation Function
def test_model(model):
    model.eval()
    total = correct = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy:.2f}%')

# Training and evaluation
train_model(model, criterion, optimizer)
test_model(model)
# Out:
# Epoch [1/1], Loss: 4.1982
# Epoch [1/1], Loss: 4.4555
# Epoch [1/1], Loss: 4.1850
# Epoch [1/1], Loss: 4.1088
# Epoch [1/1], Loss: 3.9691
# Epoch [1/1], Loss: 3.7597
# Epoch [1/1], Loss: 3.9038
# Epoch [1/1], Loss: 4.1430
# Epoch [1/1], Loss: 3.6758
# Epoch [1/1], Loss: 3.6882
# Epoch [1/1], Loss: 3.8500
# Epoch [1/1], Loss: 3.7804
# Epoch [1/1], Loss: 3.8415
# Epoch [1/1], Loss: 3.6088
# Epoch [1/1], Loss: 3.5363
# Epoch [1/1], Loss: 3.1078
# Epoch [1/1], Loss: 3.6158
# Epoch [1/1], Loss: 3.5500
# Epoch [1/1], Loss: 3.6677
# Epoch [1/1], Loss: 3.3121
# Epoch [1/1], Loss: 2.9518
# Epoch [1/1], Loss: 3.1751
# Epoch [1/1], Loss: 3.0420
# Epoch [1/1], Loss: 3.0811
# Epoch [1/1], Loss: 3.1652
# Epoch [1/1], Loss: 2.8551
# Epoch [1/1], Loss: 3.0794
# Epoch [1/1], Loss: 2.9631
# Epoch [1/1], Loss: 3.0492
# Epoch [1/1], Loss: 3.0934
# Epoch [1/1], Loss: 2.9691
# Epoch [1/1], Loss: 2.9861
# Epoch [1/1], Loss: 2.6370
# Epoch [1/1], Loss: 2.6788
# Epoch [1/1], Loss: 2.5723
# Epoch [1/1], Loss: 2.6045
# Epoch [1/1], Loss: 2.8104
# Epoch [1/1], Loss: 2.4457
# Epoch [1/1], Loss: 2.2414
# Epoch [1/1], Loss: 2.3359
# Epoch [1/1], Loss: 2.2677
# Epoch [1/1], Loss: 2.4820
# Epoch [1/1], Loss: 2.5091
# Epoch [1/1], Loss: 2.3108
# Epoch [1/1], Loss: 2.3479
# Epoch [1/1], Loss: 2.5041
# Epoch [1/1], Loss: 1.9594
# Epoch [1/1], Loss: 2.1127
# Epoch [1/1], Loss: 2.1031
# Epoch [1/1], Loss: 2.1049
# Epoch [1/1], Loss: 2.2509
# Epoch [1/1], Loss: 2.3949
# Epoch [1/1], Loss: 2.0607
# Epoch [1/1], Loss: 1.9137
# Epoch [1/1], Loss: 1.9000
# Epoch [1/1], Loss: 1.6552
# Epoch [1/1], Loss: 2.1433
# Epoch [1/1], Loss: 2.2456
# Epoch [1/1], Loss: 1.7272
# Epoch [1/1], Loss: 1.4919
# Epoch [1/1], Loss: 1.8750
# Epoch [1/1], Loss: 1.6314
# Epoch [1/1], Loss: 1.7623
# Epoch [1/1], Loss: 1.7778
# Epoch [1/1], Loss: 1.8538
# Epoch [1/1], Loss: 1.6039
# Epoch [1/1], Loss: 1.8527
# Epoch [1/1], Loss: 1.8372
# Epoch [1/1], Loss: 1.8299
# Epoch [1/1], Loss: 1.7667
# Epoch [1/1], Loss: 1.8096
# Epoch [1/1], Loss: 1.4886
# Epoch [1/1], Loss: 1.6772
# Epoch [1/1], Loss: 1.2446
# Epoch [1/1], Loss: 1.6240
# Epoch [1/1], Loss: 1.2943
# Epoch [1/1], Loss: 1.2547
# Epoch [1/1], Loss: 0.9881
# Epoch [1/1], Loss: 1.4795
# Epoch [1/1], Loss: 1.3759
# Epoch [1/1], Loss: 1.2119
# Epoch [1/1], Loss: 1.6232
# Epoch [1/1], Loss: 1.4399
# Epoch [1/1], Loss: 1.3733
# Epoch [1/1], Loss: 1.3130
# Epoch [1/1], Loss: 1.2839
# Epoch [1/1], Loss: 1.3961
# Epoch [1/1], Loss: 1.0171
# Epoch [1/1], Loss: 1.0826
# Epoch [1/1], Loss: 1.3571
# Epoch [1/1], Loss: 1.3472
# Epoch [1/1], Loss: 1.3836
# Epoch [1/1], Loss: 1.1465
# Epoch [1/1], Loss: 1.1189
# Epoch [1/1], Loss: 1.3076
# Epoch [1/1], Loss: 1.0305
# Epoch [1/1], Loss: 1.1677
# Epoch [1/1], Loss: 1.1945
# Epoch [1/1], Loss: 1.1169
# Epoch [1/1], Loss: 1.0638
# Epoch [1/1], Loss: 0.8636
# Epoch [1/1], Loss: 0.8614
# Epoch [1/1], Loss: 1.0611
# Epoch [1/1], Loss: 1.1374
# Epoch [1/1], Loss: 0.8887
# Epoch [1/1], Loss: 0.9135
# Epoch [1/1], Loss: 0.8577
# Epoch [1/1], Loss: 0.9029
# Epoch [1/1], Loss: 1.1629
# Epoch [1/1], Loss: 0.8899
# Epoch [1/1], Loss: 0.8784
# Epoch [1/1], Loss: 1.0571
# Epoch [1/1], Loss: 0.7792
# Epoch [1/1], Loss: 0.7588
# Epoch [1/1], Loss: 0.8594
# Epoch [1/1], Loss: 0.9823
# Epoch [1/1], Loss: 0.6142
# Epoch [1/1], Loss: 0.7121
# Epoch [1/1], Loss: 0.7131
# Epoch [1/1], Loss: 0.8727
# Epoch [1/1], Loss: 0.8106
# Epoch [1/1], Loss: 0.8010
# Epoch [1/1], Loss: 0.7742
# Epoch [1/1], Loss: 0.8132
# Epoch [1/1], Loss: 0.5869
# Epoch [1/1], Loss: 0.6947
# Epoch [1/1], Loss: 0.6639
# Epoch [1/1], Loss: 0.8095
# Epoch [1/1], Loss: 0.5271
# Epoch [1/1], Loss: 0.5124
# Epoch [1/1], Loss: 0.6296
# Epoch [1/1], Loss: 0.7837
# Epoch [1/1], Loss: 0.4990
# Epoch [1/1], Loss: 0.7409
# Epoch [1/1], Loss: 0.6145
# Epoch [1/1], Loss: 0.6262
# Epoch [1/1], Loss: 0.6002
# Epoch [1/1], Loss: 0.7632
# Epoch [1/1], Loss: 0.7117
# Epoch [1/1], Loss: 0.6541
# Epoch [1/1], Loss: 0.6504
# Epoch [1/1], Loss: 0.5018
# Epoch [1/1], Loss: 0.6036
# Epoch [1/1], Loss: 0.6492
# Epoch [1/1], Loss: 0.6773
# Epoch [1/1], Loss: 0.6326
# Epoch [1/1], Loss: 0.6645
# Epoch [1/1], Loss: 0.6213
# Epoch [1/1], Loss: 0.6584
# Epoch [1/1], Loss: 0.6484
# Epoch [1/1], Loss: 0.8173
# Epoch [1/1], Loss: 0.4922
# Epoch [1/1], Loss: 0.7696
# Epoch [1/1], Loss: 0.6141
# Epoch [1/1], Loss: 0.5497
# Epoch [1/1], Loss: 0.5514
# Epoch [1/1], Loss: 0.3930
# Epoch [1/1], Loss: 0.4905
# Epoch [1/1], Loss: 0.5630
# Epoch [1/1], Loss: 0.3825
# Epoch [1/1], Loss: 0.4516
# Epoch [1/1], Loss: 0.6245
# Epoch [1/1], Loss: 0.4788
# Epoch [1/1], Loss: 0.6172
# Epoch [1/1], Loss: 0.6639
# Epoch [1/1], Loss: 0.5321
# Epoch [1/1], Loss: 0.4216
# Epoch [1/1], Loss: 0.2985
# Epoch [1/1], Loss: 0.5934
# Epoch [1/1], Loss: 0.4782
# Epoch [1/1], Loss: 0.4619
# Epoch [1/1], Loss: 0.4590
# Epoch [1/1], Loss: 0.5652
# Epoch [1/1], Loss: 0.4479
# Epoch [1/1], Loss: 0.5787
# Epoch [1/1], Loss: 0.4202
# Epoch [1/1], Loss: 0.3206
# Epoch [1/1], Loss: 0.4165
# Epoch [1/1], Loss: 0.5167
# Epoch [1/1], Loss: 0.4109
# Epoch [1/1], Loss: 0.4143
# Epoch [1/1], Loss: 0.3664
# Epoch [1/1], Loss: 0.4934
# Epoch [1/1], Loss: 0.3167
# Epoch [1/1], Loss: 0.2785
# Test Accuracy: 95.53%
